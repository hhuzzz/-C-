# %%
import pandas as pd
data=pd.read_csv('data.csv')

# %%
data
# Out:
#       磁芯材料  温度，oC   频率，Hz      磁芯损耗，w/m3 励磁波形  0（磁通密度B，T）         1         2  \
# 0      材料1     25   50030    1997.955250  正弦波    0.000213  0.000389  0.000566
# 1      材料1     25   50020    2427.749830  正弦波   -0.000551 -0.000358 -0.000165
# 2      材料1     25   50020    3332.725760  正弦波   -0.003780 -0.003564 -0.003349
# 3      材料1     25   50020    4502.908007  正弦波   -0.000511 -0.000267 -0.000023
# 4      材料1     25   50030    6063.023248  正弦波    0.000458  0.000732  0.001007
# ...    ...    ...     ...            ...  ...         ...       ...       ...
# 12395  材料4     90  199190   20604.900210  梯形波   -0.017758 -0.017339 -0.016932
# 12396  材料4     90  199190   26504.284280  梯形波   -0.019690 -0.019227 -0.018776
# 12397  材料4     90  199190   46232.491530  梯形波   -0.024998 -0.024411 -0.023838
# 12398  材料4     90  199190   61458.085900  梯形波   -0.027988 -0.027329 -0.026687
# 12399  材料4     90  199190  107581.189300  梯形波   -0.035228 -0.034397 -0.033586
#
# ...

# %%
data=data[['磁芯损耗，w/m3','磁芯材料', '温度，oC', '励磁波形']]
data.columns=['磁芯损耗', '磁芯材料','温度',  '励磁波形']
data
# Out:
#                 磁芯损耗 磁芯材料  温度 励磁波形
# 0        1997.955250  材料1  25  正弦波
# 1        2427.749830  材料1  25  正弦波
# 2        3332.725760  材料1  25  正弦波
# 3        4502.908007  材料1  25  正弦波
# 4        6063.023248  材料1  25  正弦波
# ...              ...  ...  ..  ...
# 12395   20604.900210  材料4  90  梯形波
# 12396   26504.284280  材料4  90  梯形波
# 12397   46232.491530  材料4  90  梯形波
# 12398   61458.085900  材料4  90  梯形波
# 12399  107581.189300  材料4  90  梯形波
#
# [12400 rows x 4 columns]

# %%
data
# Out:
#                 磁芯损耗 磁芯材料  温度 励磁波形
# 0        1997.955250  材料1  25  正弦波
# 1        2427.749830  材料1  25  正弦波
# 2        3332.725760  材料1  25  正弦波
# 3        4502.908007  材料1  25  正弦波
# 4        6063.023248  材料1  25  正弦波
# ...              ...  ...  ..  ...
# 12395   20604.900210  材料4  90  梯形波
# 12396   26504.284280  材料4  90  梯形波
# 12397   46232.491530  材料4  90  梯形波
# 12398   61458.085900  材料4  90  梯形波
# 12399  107581.189300  材料4  90  梯形波
#
# [12400 rows x 4 columns]

# %%
data['温度'].unique()
# Out:
# array([25, 50, 70, 90], dtype=int64)

# %%
data['温度']=data['温度'].astype(str)+'度'
# Out:
# <ipython-input-17-e9298f7d4f5c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['温度']=data['温度'].astype(str)+'度'

# %%
data
# Out:
#                 磁芯损耗 磁芯材料   温度 励磁波形
# 0        1997.955250  材料1  25度  正弦波
# 1        2427.749830  材料1  25度  正弦波
# 2        3332.725760  材料1  25度  正弦波
# 3        4502.908007  材料1  25度  正弦波
# 4        6063.023248  材料1  25度  正弦波
# ...              ...  ...  ...  ...
# 12395   20604.900210  材料4  90度  梯形波
# 12396   26504.284280  材料4  90度  梯形波
# 12397   46232.491530  材料4  90度  梯形波
# 12398   61458.085900  材料4  90度  梯形波
# 12399  107581.189300  材料4  90度  梯形波
#
# [12400 rows x 4 columns]

# %%
data.to_csv('Q3_data.csv',index=None)
#具体分析详看代码视频讲解
